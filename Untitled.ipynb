# %%
import cv2
import pydicom
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/vishc1/anaconda3/envs/hoang/lib/python3.9/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (None)/charset_normalizer (3.1.0) doesn't match a supported version!
#   warnings.warn(

# %%
import os

# %%
sample = os.listdir('../VinDr_Mammo/physionet.org/files/vindr-mammo/1.0.0/images')
path= '../VinDr_Mammo/physionet.org/files/vindr-mammo/1.0.0/images'

# %%
len(sample)
# Out:
# 5001

# %%
i = np.random.choice(len(sample),1)[0]
view1= os.listdir(path+'/'+sample[i])[0]
ds= pydicom.dcmread(path+'/'+ sample[i]+'/'+view1)

# %%
img= ds.pixel_array

# %%
img= img/img.max()
#img = img.astype('float32')
img= np.expand_dims(img,2)
img= np.repeat(img,3,axis=2)
img.shape
# Out:
# (3518, 2800, 3)

# %%
plt.imshow(img)

# %%
from datasets import CustomDataset2
